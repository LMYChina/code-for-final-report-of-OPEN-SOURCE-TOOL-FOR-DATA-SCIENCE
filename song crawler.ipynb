# %%
 
import urllib.parse
from urllib.request import urlopen
import json
import time
import sys
import os
 
def processbar():
    for i in range(1, 51):
        sys.stdout.write('\r')
        sys.stdout.write('{0}% |{1}'.format(int(i % 51) * 2, int(i % 51) * '■'))
        sys.stdout.flush()
        time.sleep(0.125)
    sys.stdout.write('\n')
 
def KuGou_music():
    keyword = urllib.parse.urlencode({'keyword': input('请输入歌名:')})
    keyword = keyword[keyword.find('=') + 1:]
    url = 'https://songsearch.kugou.com/song_search_v2?callback=jQuery11240251602301830425_1548735800928&keyword=' + keyword + '&page=1&pagesize=30&userid=-1&clientver=&platform=WebFilter&tag=em&filter=2&iscorrection=1&privilege_filter=0&_=1548735800930'
    content = urlopen(url=url)
    content = content.read().decode('utf-8')
    str_1 = content[content.find('(') + 1:-2]
    str_2 = json.loads(str_1)
    Music_Hash = {}
    Music_id = {}
    for dict_1 in str_2['data']['lists']:
        Music_Hash[dict_1['FileName']] = dict_1['FileHash']
        Music_id[dict_1['FileName']] = dict_1['AlbumID']
 
    list_music_1 = [music for music in Music_Hash]
    list_music = [music for music in Music_Hash]
 
    for i in range(len(list_music)):
        if '- <em>' in list_music[i]:
            list_music[i] = list_music[i].replace('- <em>', '-')
        if '</em>' in list_music[i]:
            list_music[i] = list_music[i].replace('</em>', '')
        if '<em>' in list_music[i]:
            list_music[i] = list_music[i].replace('<em>', '')
 
    for i in range(len(list_music)):
        print("{}-:{}".format(i + 1, list_music[i]))
 
    music_id_1 = int(input('请输入你想下载的歌曲序号:'))
 
    url = 'https://wwwapi.kugou.com/yy/index.php?r=play/getdata&hash=' + Music_Hash[
        list_music_1[music_id_1 - 1]] + '&album_id=' + Music_id[list_music_1[
        music_id_1 - 1]] + '&dfid=1txZyw3NzGKI0eYLrj4SDwL3&mid=73dd8587e7d1ebd1486c518cee7b5e55&platid=4'
    js_content = urlopen(url=url)
    str_3 = js_content.read().decode('utf-8')
    dict_2 = json.loads(str_3)
 
    try:
        music_href = dict_2['data']['play_backup_url']
 
        music_content = urlopen(url=music_href).read()
        try:
 
            os.mkdir('D:/爬虫爬取/MP3/')
        except Exception as e:
            print(e, '稍等,程序仍然执行')
        finally:
            music_path = 'D:/爬虫爬取/MP3/' + list_music[music_id_1 - 1] + '.mp3'  # 歌曲下载路径
            with open(music_path, 'wb') as f:
                print('正在下载当中...')
                f.write(music_content)
                processbar()
                print('{}.mp3下载成功！'.format(list_music[music_id_1 - 1]))
 
    except:
        print('对不起，没有该歌曲的版权！')
 
 
if __name__ == '__main__':
    KuGou_music()
# Out:
# 1-:Eminem - Without Me
# 2-:Eminem、Rihanna - Love The Way You Lie
# 3-:Eminem、Rihanna - The Monster
# 4-:Eminem、Dido - Stan
# 5-:Eminem - Without Me (DJ版)
# 6-:Eminem - Lose Yourself
# 7-:Rihanna、Eminem - Love The Way You Lie (Part II)
# 8-:Eminem、Nate Dogg - Shake That (Explicit)
# 9-:Eminem - Lose Yourself (Explicit)
# 10-:Eminem - Rap God
# 11-:Dr. Dre、Eminem、Skylar Grey - I Need a Doctor (Explicit)
# 12-:Eminem - Not Afraid
# 13-:Eminem - Mockingbird (Explicit)
# 14-:Eminem - The Real Slim Shady (Explicit)
# 15-:Eminem - Business
# 16-:Eminem - Venom (Explicit)
# 17-:Eminem、Nate Dogg - 'Till I Collapse
# 18-:Eminem、Juice WRLD - Godzilla (Explicit)
# 19-:Xzibit、Eminem、Nate Dogg - My Name (Explicit Version)
# 20-:Eminem - Space Bound (Explicit)
# 21-:Eminem、Leona Lewis、2Pac - Mockingbird+Better in Time+Dear Mama
# 22-:Bruno Mars、Eminem、Royce da 5'9" - Lighters
# 23-:Eminem - Beautiful (Explicit)
# 24-:Eminem、50 Cent、Cashis、Lloyd Banks - You Don't Know (Explicit)
# 25-:Eminem - Fall (Explicit)
# 26-:Eminem - Sing For The Moment
# 27-:Skylar Grey、Polo G、Mozzy、Eminem - Last One Standing (Explicit)
# 28-:Eminem、50 Cent、2Pac - Till I Collapse (Remix)
# 29-:Eminem、Sia - Beautiful Pain (Explicit)
# 30-:Rihanna、Eminem - Love The Way You Lie+I need a doctor (2011第53届格莱美现场)
# [WinError 183] 当文件已存在时，无法创建该文件。: 'D:/爬虫爬取/MP3/' 稍等,程序仍然执行
# 正在下载当中...
# 100% |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■
# Eminem - Without Me.mp3下载成功！
